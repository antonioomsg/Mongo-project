# %%
import pandas as pd
from IPython.display import Image
from pymongo import MongoClient
from in_put.senoicnuf import *

# %%
from pymongo import MongoClient
dbName = "companies"
mongodbURL = f"mongodb://localhost/{dbName}"
client = MongoClient(mongodbURL, connectTimeoutMS=2000, serverSelectionTimeoutMS=2000)
db = client.get_database()

# %%
client = MongoClient("mongodb://localhost/companies")
db = client.get_database()

# %%
#Este es un Starbuck al azar.
Mountain_star={'type': 'Point', 'coordinates': [-122.083068, 37.387571]}

# %%
Mountain_star
# Out:
# {'type': 'Point', 'coordinates': [-122.083068, 37.387571]}

# %%
#aplicamos la funcion near para sacar las oficinas cerca del starbuck elegido.
q = db.clean_ca_USA.find(geoQueryNear(Mountain_star, radius=100),{"_id":0,"company_id":0})
near_offices_Mountain_View_st = list(q)
len(near_offices_Mountain_View_st)
# Out:
# 2

# %%
df = pd.DataFrame(near_offices_Mountain_View_st)
df.to_json("../input/near_offices_Mountain_View_st.json",orient="records")

# %%
from PIL import Image                                                                                
Image.open('../input/Foto1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=395x309 at 0x7FB73200F040>

# %%
Image.open('../input/Foto2.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=350x321 at 0x7FB732A86B50>
